# %% [markdown]
# <a href="https://colab.research.google.com/github/Omayer-Chowdhury/first-time/blob/main/text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is heading

# %% [markdown]
# **This is bold line**

# %% [markdown]
# [Google](https://www.google.com)

# %% [markdown]
# ![omayer.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# $$(a+b)^2 = a^2+2ab+b^2$$
# double dollar sign for align center.
# single dollar sign for mathematics formate.

# %% [markdown]
# $ x1 = \frac{-b+\sqrt{b^2-4ac}}{2a}$
